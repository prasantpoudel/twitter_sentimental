# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
data=pd.read_csv('data.csv')
data
# Out:
#     Unnamed: 0                                             Tweets  \
# 0            0              How about supporting sex trafficking?
# 1            1   Old enough to remember when people would read...
# 2            2        $100 • 24 Hours  - &amp; Follow 325JPracing
# 3            3   If you leave your bitcoin on an exchange it's...
# 4            4   1. Hearing People losing their life Savings, ...
# ..         ...                                                ...
# 85          95  Congrats to the winner of the 1 Bitcoin giveaw...
# 86          96   Forget the distractions America.  The most im...
# 87          97  I  learnt that Someone actually won the 1 Bitc...
# 88          98                 Imagine if Putin created Bitcoin
# 89          99    they had the chance to create a real decentr...
#
#                                              mentions  \
# 0                                      ['@TODAYshow']
# 1                                   ['@SolanaLegend']
# 2   ['@ZaraGiveaway', '@metamonopoly', '@LucasGive...
# 3                                ['@SimplyBitcoinTV']
# 4                                     ['@EmperorBTC']
# ..                                                ...
# 85                                ['@yellowcard_app']
# 86                               ['@digitalassetbuy']
# 87                                ['@yellowcard_app']
# 88                                                 []
# 89                       ['@saylor', '@sailortrades']
#
#                     hastags                    links             retweets  \
# 0                        []                      NaN                  NaN
# 1                        []                      NaN     RT @SolanaLegend
# 2                        []                      NaN     RT @ZaraGiveaway
# 3              ['#bitcoin']  https://t.co/qkT5ettSyb  RT @SimplyBitcoinTV
# 4                        []                      NaN       RT @EmperorBTC
# ..                      ...                      ...                  ...
# 85  ['#AWholeInYourWallet']  https://t.co/DNdbvdPRf6                  NaN
# 86                       []                      NaN  RT @digitalassetbuy
# 87  ['#AWholeInYourWallet']  https://t.co/z4twmUhskP                  NaN
# 88                       []  https://t.co/hbVm2IQ7ie                  NaN
# 89                       []                      NaN                  NaN
#
#     Subjectivity  Polarity  Analysis
# 0       0.250000  0.250000  Positive
# 1       0.400000  0.033333  Positive
# 2       0.000000  0.000000   Neutral
# 3       0.000000  0.000000   Neutral
# 4       0.000000  0.000000   Neutral
# ..           ...       ...       ...
# 85      0.500000  0.400000  Positive
# 86      0.750000  0.450000  Positive
# 87      0.426548  0.157738  Positive
# 88      0.000000  0.000000   Neutral
# 89      0.395000 -0.030000  Negative
#
# [90 rows x 9 columns]

# %%
def analyse_hastag(data):

    hastag = pd.DataFrame(data["hastags"].to_list()).add_prefix("hastag_")

    try:
        hastag = pd.concat([hastag["hastag_0"], hastag["hastag_1"], hastag["hastag_2"]], ignore_index=True)
    except:
        hastag = pd.concat([hastag["hastag_0"]], ignore_index=True)
    
    hastag = hastag.value_counts().head(10)
#     logging.info('analyse_hastag data function call and return of data')
    return hastag

# %%
hashtag=analyse_hastag(data)

# %%
hashtag
# Out:
# hastag_0
# []                                                                 37
# ['#Bitcoin']                                                       24
# ['#AWholeInYourWallet']                                             2
# ['#Bitcoin', '#BTC', '#LN', '#LightningNetwork', '#boltcoiner']     2
# ['#Bitcoin', '#BTC']                                                2
# ['#bitcoin']                                                        2
# ['#DragonList']                                                     2
# ['#ME']                                                             1
# ['#qlc', '#Crypto', '#Bitcoin']                                     1
# ['#pos']                                                            1
# dtype: int64

# %%
hashtag
# Out:
# []                                                                 37
# ['#Bitcoin']                                                       24
# ['#Bitcoin', '#BTC']                                                2
# ['#Bitcoin', '#BTC', '#LN', '#LightningNetwork', '#boltcoiner']     2
# ['#bitcoin']                                                        2
# ['#AWholeInYourWallet']                                             2
# ['#DragonList']                                                     2
# ['#1892', '#generative', '#ArtonBitcoin']                           1
# ['#Ordinals']                                                       1
# ['#BitApes', '#Bitcoin']                                            1
# Name: hastag_0, dtype: int64

# %%
def analyse_hastag(data):

    hastag = pd.DataFrame(data["hastags"].to_list()).add_prefix("hastag_")


#     hastag = pd.concat([hastag["hastag_0"], hastag["hastag_1"], hastag["hastag_2"]], ignore_index=True)
#     except:
    hastag = pd.concat([hastag["hastag_0"]], ignore_index=True)
    
    hastag = hastag.value_counts().head(10)
#     logging.info('analyse_hastag data function call and return of data')
    return hastag

# %%
hashtag=analyse_hastag(data)
hashtag
# Out:
# []                                                                 37
# ['#Bitcoin']                                                       24
# ['#Bitcoin', '#BTC']                                                2
# ['#Bitcoin', '#BTC', '#LN', '#LightningNetwork', '#boltcoiner']     2
# ['#bitcoin']                                                        2
# ['#AWholeInYourWallet']                                             2
# ['#DragonList']                                                     2
# ['#1892', '#generative', '#ArtonBitcoin']                           1
# ['#Ordinals']                                                       1
# ['#BitApes', '#Bitcoin']                                            1
# Name: hastag_0, dtype: int64

# %%
def cloud(data):
    text = " ".join(cat.split()[1] for cat in data)
    word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
    
    return word_cloud

# %%
wordcloud=cloud(data['Tweets'])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def mention_data(data):
    mention = pd.DataFrame(data["mentions"].to_list()).add_prefix("mention_")
#  
#     mention = pd.concat([mention["mention_0"], mention["mention_1"], mention["mention_2"]], ignore_index=True)
#     except:
    mention = pd.concat([mention["mention_0"]], ignore_index=True)
    
    mention = mention.value_counts().head(10)
    
    return mention

# %%
mention=mention_data(data)
mention
# Out:
# []                                                                                        14
# ['@ZaraGiveaway', '@metamonopoly', '@LucasGiveaways', '@LM0325_JP', '@bitcoin_racing']     5
# ['@BitcoinMagazine']                                                                       4
# ['@BTC_Archive']                                                                           3
# ['@digitalassetbuy']                                                                       3
# ['@yellowcard_app']                                                                        2
# ['@AltcoinDailyio']                                                                        2
# ['@Coredao_Org']                                                                           2
# ['@saylor', '@sailortrades']                                                               2
# ['@rovercrc']                                                                              2
# Name: mention_0, dtype: int64

# %%
def mention_data(data):
    mention = pd.DataFrame(data["mentions"].to_list()).add_prefix("mention_")
#  
#     mention = pd.concat([mention["mention_0"], mention["mention_1"], mention["mention_2"]], ignore_index=True)
#     except:
#     mention = pd.concat([mention["mention_0"]], ignore_index=True)
    
    mention = mention.value_counts().head(10)
    
    return mention

# %%
mention=mention_data(data)
mention
# Out:
# mention_0
# []                                                                                        14
# ['@ZaraGiveaway', '@metamonopoly', '@LucasGiveaways', '@LM0325_JP', '@bitcoin_racing']     5
# ['@BitcoinMagazine']                                                                       4
# ['@BTC_Archive']                                                                           3
# ['@digitalassetbuy']                                                                       3
# ['@DragonOrdinals']                                                                        2
# ['@yellowcard_app']                                                                        2
# ['@saylor', '@sailortrades']                                                               2
# ['@rovercrc']                                                                              2
# ['@_bitcoiner', '@boltcoiner']                                                             2
# dtype: int64

# %%
import tweepy as tw
import configparser

# %%
def twitter_connection():
    config=configparser.ConfigParser()
    config.read("config.ini")

    api_key=config["twitter"]["consumerKey"]
    api_key_secret = config["twitter"]["consumerSecret"]
    access_token = config["twitter"]["accessToken"]
    access_token_secret=config["twitter"]["accessTokenSecret"]
    auth = tw.OAuthHandler(api_key, api_key_secret)
#     auth.set_access_token("access_token", "access_token_secret")
    api = tw.API(auth)
    return api

# %%
api=twitter_connection()

# %%
query='prasant'
tweet_number=10
posts = tw.Cursor(api.user_timeline, screen_name=query, count = 200, tweet_mode="extended").items((tweet_number))
data  = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
print(data)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# Cell In[76], line 4
#       2 tweet_number=10
#       3 posts = tw.Cursor(api.user_timeline, screen_name=query, count = 200, tweet_mode="extended").items((tweet_number))
# ----> 4 data  = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
#       5 print(data)
#
# Cell In[76], line 4, in <listcomp>(.0)
#       2 tweet_number=10
#       3 posts = tw.Cursor(api.user_timeline, screen_name=query, count = 200, tweet_mode="extended").items((tweet_number))
# ----> 4 data  = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
#       5 print(data)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:577, in API.user_timeline(self, **kwargs)
#     536 @pagination(mode='id')
#     537 @payload('status', list=True)
#     538 def user_timeline(self, **kwargs):
#     539     """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
#     540                      trim_user, exclude_replies, include_rts)
#     541
#    (...)
#     575     https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-user_timeline
#     576     """
# --> 577     return self.request(
#     578         'GET', 'statuses/user_timeline', endpoint_parameters=(
#     579             'user_id', 'screen_name', 'since_id', 'count', 'max_id',
#     580             'trim_user', 'exclude_replies', 'include_rts'
#     581         ), **kwargs
#     582     )
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:263, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     261     raise BadRequest(resp)
#     262 if resp.status_code == 401:
# --> 263     raise Unauthorized(resp)
#     264 if resp.status_code == 403:
#     265     raise Forbidden(resp)
#
# Unauthorized: 401 Unauthorized
# 32 - Could not authenticate you.

# %%
config=configparser.ConfigParser()
config.read("config.ini")

api_key=config["twitter"]["consumerKey"]
api_key_secret = config["twitter"]["consumerSecret"]
access_token = config["twitter"]["accessToken"]
access_token_secret=config["twitter"]["accessTokenSecret"]
# auth = tw.OAuthHandler(api_key, api_key_secret)
# auth.set_access_token("access_token", "access_token_secret")
# api = tw.API(auth)
auth = tw.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True)
hastag='#stockmarket'
query=tw.Cursor(api.search_tweets,q=hastag).items(4)
tweets=[{'Tweets':tweet.text} for tweet in query]
print(tweets)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[82], line 16
#      14 hastag='#stockmarket'
#      15 query=tw.Cursor(api.search_tweets,q=hastag).items(4)
# ---> 16 tweets=[{'Tweets':tweet.text} for tweet in query]
#      17 print(tweets)
#
# Cell In[82], line 16, in <listcomp>(.0)
#      14 hastag='#stockmarket'
#      15 query=tw.Cursor(api.search_tweets,q=hastag).items(4)
# ---> 16 tweets=[{'Tweets':tweet.text} for tweet in query]
#      17 print(tweets)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:1309, in API.search_tweets(self, q, **kwargs)
#    1215 @pagination(mode='id')
#    1216 @payload('search_results')
#    1217 def search_tweets(self, q, **kwargs):
#    1218     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1219                      until, since_id, max_id, include_entities)
#    1220
#    (...)
#    1307     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1308     """
# -> 1309     return self.request(
#    1310         'GET', 'search/tweets', endpoint_parameters=(
#    1311             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1312             'until', 'since_id', 'max_id', 'include_entities'
#    1313         ), q=q, **kwargs
#    1314     )
#
# File ~/miniconda3/lib/python3.10/site-packages/tweepy/api.py:261, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     259 self.last_response = resp
#     260 if resp.status_code == 400:
# --> 261     raise BadRequest(resp)
#     262 if resp.status_code == 401:
#     263     raise Unauthorized(resp)
#
# BadRequest: 400 Bad Request
# 215 - Bad Authentication data.
